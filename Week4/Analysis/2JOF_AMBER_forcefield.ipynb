# %%
import numpy as np
import mdtraj as md
import matplotlib.pyplot as plt

traj=md.load('step5_combined_wrap.xtc',top='step5_combined_wrap.gro')

# compute the distance between the first and last atom of each frame
def end_end(traj):
    # get the first and last atom
    first = traj.xyz[:,0,:]
    last = traj.xyz[:,-1,:]
    # compute the distance between the first and last atom
    dist = np.sqrt(np.sum((first-last)**2, axis=1))
    return dist

# compute the distance between the first and last atom
dist = end_end(traj)
print(dist)

# the simulation time (in picoseconds)
print(traj.time)
# Out:
# [1.190571   1.1798654  1.0773087  1.0942075  1.1147422  1.3123628
#  1.3589019  1.1262065  0.9570006  1.1211637  1.0481924  1.26498
#  1.237897   1.4138261  1.3561704  1.1400784  1.1278386  0.97316384
#  1.2153585  1.1967106  1.1789937  1.0242544  1.202668   1.1820331
#  0.81958836 0.8968193  0.8376759  0.5945914  0.44888088 0.7323721
#  1.0367961  1.2300094  1.0052209  1.1534857  1.2887144  1.1534389
#  1.0383165  1.1382998  1.3253945  1.2221892  1.1360005  1.2907262
#  1.2941544  1.243369   0.9021519  1.0625917  1.0352558  1.215474
#  1.6346331  1.4242038  1.500327   1.408354   1.3632965  0.97249484
#  1.410374   1.1155492  1.2759385  1.262707   0.9817214  1.1704822
#  1.2833476  1.1359019  1.2722179  1.3871025  1.327263   0.975523
#  1.306851   1.3070383  1.2451838  1.220191   1.3571274  1.4924082
#  1.4311216  1.564372   1.1792107  1.4541208  1.2921696  1.4159418
#  1.2735957  1.2222389  1.3148142  1.215043   1.0195318  1.3890263
#  1.1446389  1.4234767  1.1130868  1.280352   1.4787407  1.3359482
#  1.3449771  1.352459   1.3416322  1.2390784  1.0046105  1.0481423
#  1.2588491  0.9384823  1.2552555  1.2104582  0.96965367]
# [    0.   100.   200.   300.   400.   500.   600.   700.   800.   900.
#   1000.  1100.  1200.  1300.  1400.  1500.  1600.  1700.  1800.  1900.
#   2000.  2100.  2200.  2300.  2400.  2500.  2600.  2700.  2800.  2900.
#   3000.  3100.  3200.  3300.  3400.  3500.  3600.  3700.  3800.  3900.
#   4000.  4100.  4200.  4300.  4400.  4500.  4600.  4700.  4800.  4900.
#   5000.  5100.  5200.  5300.  5400.  5500.  5600.  5700.  5800.  5900.
#   6000.  6100.  6200.  6300.  6400.  6500.  6600.  6700.  6800.  6900.
#   7000.  7100.  7200.  7300.  7400.  7500.  7600.  7700.  7800.  7900.
#   8000.  8100.  8200.  8300.  8400.  8500.  8600.  8700.  8800.  8900.
#   9000.  9100.  9200.  9300.  9400.  9500.  9600.  9700.  9800.  9900.
#  10000.]

# %%
# Compute the radius of gyration for every frame.
Rgndarray = md.compute_rg(traj, masses=None)
Rgndarray
# Out:
# array([0.74294288, 0.73862874, 0.73807473, 0.73369427, 0.71685326,
#        0.73596719, 0.73337076, 0.72684798, 0.73150959, 0.73507566,
#        0.73513553, 0.74242271, 0.73657563, 0.73530068, 0.75045769,
#        0.72178124, 0.75213995, 0.72535443, 0.72956965, 0.73228231,
#        0.7381113 , 0.73828117, 0.73765635, 0.74071327, 0.73609388,
#        0.74041627, 0.75067782, 0.73503423, 0.75070043, 0.74286792,
#        0.75379644, 0.7369589 , 0.74507785, 0.73590694, 0.74629684,
#        0.71634651, 0.73238386, 0.73259439, 0.74083227, 0.73918795,
#        0.74926185, 0.75092829, 0.73669869, 0.73037273, 0.73478974,
#        0.74654423, 0.74437169, 0.77398169, 0.72949554, 0.73593462,
#        0.73668037, 0.73300244, 0.73693665, 0.75170637, 0.77779784,
#        0.75683444, 0.75157156, 0.73714759, 0.7460999 , 0.74637663,
#        0.74939788, 0.73891023, 0.73998549, 0.75974331, 0.75525743,
#        0.74841989, 0.7440838 , 0.74713243, 0.7297915 , 0.72975779,
#        0.73076107, 0.75134269, 0.73961727, 0.75678968, 0.77496178,
#        0.74753563, 0.73397355, 0.73348824, 0.71752365, 0.72968744,
#        0.73133863, 0.73311712, 0.73729142, 0.74259696, 0.74104711,
#        0.73488046, 0.72869793, 0.72960736, 0.75560221, 0.73963803,
#        0.7332365 , 0.73610346, 0.73705176, 0.73968435, 0.72402949,
#        0.73561302, 0.74239971, 0.7480666 , 0.75901262, 0.74937931,
#        0.73989188])

# %%
plt.plot(traj.time/1000, dist, label= "End to End Distance")           #plot distance vs time
plt.legend()                     
plt.xlabel('Time (ps)')
plt.ylabel('End to End Distance(nm)')
plt.title('End to End Distance VS Time')
plt.savefig("../Figures/2JOF_End2EndDistance.png",format="png")
print("Plot saved: ../Figures/2JOF_End2EndDistance.pdf")
plt.show()
# Out:
# Plot saved: ../Figures/2JOF_End2EndDistance.pdf

# %%
plt.plot(traj.time/1000, Rgndarray, label= "Radius of Gyration")      
plt.legend()                     
plt.xlabel('Time (ps)')
plt.ylabel('Rg(nm)')
plt.title('Radius of Gyration VS Time')
plt.savefig("../Figures/2JOF_RadiusofGyration.png",format="png")
print("Plot saved: ../Figures/2JOF_RadiusofGyration.png")
# Out:
# Plot saved: ../Figures/2JOF_RadiusofGyration.png
