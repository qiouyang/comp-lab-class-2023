# %% [markdown]
# ### Do all of Lugano exercise 2.
# Exercise 2: estimating the free energy
# [optional In addition to what is said, try either a different hill height or sigma value and see how it changes the speed of convergence]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
phi_all, freeE_all, der_phi_all = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/adp.fes.dat", skiprows=5, unpack=True)

phi_fesdat1, freeE_fesdat1, der_phi_fesdat1 = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/StrideHills/adp.fes.dat1.dat", skiprows=5, unpack=True)
phi_fesdat3, freeE_fesdat3, der_phi_fesdat3 = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/StrideHills/adp.fes.dat3.dat", skiprows=5, unpack=True)
phi_fesdat10, freeE_fesdat10, der_phi_fesdat10 = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/StrideHills/adp.fes.dat10.dat", skiprows=5, unpack=True)
phi_fesdat20, freeE_fesdat20, der_phi_fesdat20 = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/StrideHills/adp.fes.dat20.dat", skiprows=5, unpack=True)
phi_fesdat50, freeE_fesdat50, der_phi_fesdat50 = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/StrideHills/adp.fes.dat50.dat", skiprows=5, unpack=True)
phi_fesdat100, freeE_fesdat100, der_phi_fesdat100 = np.loadtxt("/home/qo210/comp-lab-class/comp-lab-class-2023-new/Week6/Inputs/Q3/StrideHills/adp.fes.dat100.dat", skiprows=5, unpack=True)

# check data we are going to plot
print('phi_all:', phi_all.shape)
print('freeE_all:', freeE_all.shape)
# Out:
# phi_all: (33,)
# freeE_all: (33,)
# phi_fesdat1: (33,)
# freeE_fesdat1: (33,)
# phi_fesdat10: (33,)
# freeE_fesdat10: (33,)
# phi_fesdat100: (33,)
# freeE_fesdat100: (33,)

# %%
# plot
plt.plot(phi_all, freeE_all, label='10ns')

# legend
plt.legend(fontsize=12)
# set all labels
plt.xlabel(r'$\phi$ (rad)', fontsize=12)
plt.ylabel('Free energy (kJ/mol)', fontsize=12)

# set all titles
plt.title("Estimates of the free energy (10ns)")

# save figure
plt.savefig("../Figures/Q4_ADP_FreeEnergy_10ns.png",format="png")
plt.show()

# %%
plt.plot(phi_fesdat1, freeE_fesdat1, label='0.1 ns')
plt.plot(phi_fesdat3, freeE_fesdat3, label='0.3 ns')
plt.plot(phi_fesdat10, freeE_fesdat10, label='1 ns')
plt.plot(phi_fesdat20, freeE_fesdat20, label='2 ns')
plt.plot(phi_fesdat50, freeE_fesdat50, label='5 ns')
plt.plot(phi_fesdat100, freeE_fesdat100, label='10 ns')
# legend
plt.legend(fontsize=12)
# set all labels
plt.xlabel(r'$\phi$ (rad)')
plt.ylabel('Free energy (kJ/mol)')

# set all titles
plt.title("Estimates of the free energy")

# save figure
plt.savefig("../Figures/Q4_ADP_FreeEnergy_StrideHills.png",format="png")
plt.show()
